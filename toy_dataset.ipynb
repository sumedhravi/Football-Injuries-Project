# %%
import pandas as pd
import random

# %%
data = pd.read_csv('./TableauData/all.csv')
data.head()
# Out:
# /Users/tyler/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (17,37,43,45,50,55,60,79,82,84,86,88,89,90,95,96,97,98,99,100,101,102,103,104,106,107,108,113,114,115,116,118,119,120,121,122,123,124,125,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                      id  index  period     timestamp  minute  \
# 0  91fdaa62-e36b-4aca-8c56-7a6d32289483      1       1  00:00:00.000       0
# 1  aae12223-7969-4f4e-ac4e-83b075af1352      2       1  00:00:00.000       0
# 2  ba7b6ef4-edab-43e9-8ed2-ccc073667b8f      3       1  00:00:00.000       0
# 3  f8f30929-e011-4ea9-bbc9-c22873023d5f      4       1  00:00:00.000       0
# 4  c0927b64-b182-4e44-83f0-b77222d600f8      5       1  00:00:00.443       0
#
# ...

# %%
data
# Out:
#                                            id  index  period     timestamp  \
# 0        91fdaa62-e36b-4aca-8c56-7a6d32289483      1       1  00:00:00.000
# 1        aae12223-7969-4f4e-ac4e-83b075af1352      2       1  00:00:00.000
# 2        ba7b6ef4-edab-43e9-8ed2-ccc073667b8f      3       1  00:00:00.000
# 3        f8f30929-e011-4ea9-bbc9-c22873023d5f      4       1  00:00:00.000
# 4        c0927b64-b182-4e44-83f0-b77222d600f8      5       1  00:00:00.443
# ...                                       ...    ...     ...           ...
# 3792072  a2becaf4-d3e5-4bf3-9459-0b442020b72a   4986       5  00:05:54.582
# 3792073  a6217adf-c93a-4229-8ea9-f1a58752ca34   4987       5  00:07:04.301
# 3792074  aa15567a-333d-4aca-9df0-173672564d43   4988       5  00:07:04.869
# 3792075  abefbcd4-a519-4879-9a28-cc09552141fc   4989       5  00:07:05.592
# 3792076  7be5fa66-8c67-40d6-8697-996775eb7ec2   4990       5  00:07:05.592
#
# ...

# %%
data.iloc[[1, 4]]
# Out:
#                                      id  index  period     timestamp  minute  \
# 1  aae12223-7969-4f4e-ac4e-83b075af1352      2       1  00:00:00.000       0
# 4  c0927b64-b182-4e44-83f0-b77222d600f8      5       1  00:00:00.443       0
#
#    second  possession  duration  type.id    type.name  ...  \
# 1       0           1   0.00000       35  Starting XI  ...
# 4       0           2   0.85577       30         Pass  ...
#
#    half_start.late_video_start goalkeeper.success_in_play  \
# 1                          NaN                        NaN
# 4                          NaN                        NaN
#
#    goalkeeper.success_out shot.follows_dribble  goalkeeper.lost_out  \
# 1                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
#
#   goalkeeper.penalty_saved_to_post  goalkeeper.saved_to_post  \
# 1                              NaN                       NaN
# ...

# %%
rand_idxs = random.sample(range(data.shape[0]), 20000)
rand_idxs
# Out:
# [1564084,
#  2100088,
#  3339276,
#  3032379,
#  3156939,
#  2170295,
#  933093,
#  703060,
#  968056,
#  2434237,
#  3543803,
#  3779145,
#  583068,
#  3367221,
#  387622,
#  304829,
#  2828168,
#  2397624,
#  474812,
#  1509222,
#  878908,
#  2687026,
#  2180908,
#  2677135,
#  3158644,
#  3566021,
#  1360248,
#  308251,
#  3507972,
#  1144657,
#  327402,
#  1842259,
#  2587722,
#  3638245,
#  3268734,
#  2258343,
#  2840604,
#  206716,
#  752727,
#  3265030,
#  1932101,
#  2946927,
#  2724974,
#  2063359,
#  90822,
#  1141385,
#  1258615,
#  1539899,
#  298799,
#  3494344,
#  574972,
#  273924,
#  203658,
#  1168849,
#  1368345,
#  3108623,
#  2273453,
#  2170307,
#  1844171,
#  3490305,
#  2161165,
#  1166088,
#  104189,
#  578823,
#  1169057,
#  960777,
#  2949160,
#  1390095,
#  1856246,
#  2610622,
#  3565713,
#  80579,
#  747041,
#  2638302,
#  3565581,
#  816345,
#  1858431,
#  855823,
#  2948564,
#  2978926,
#  3781896,
#  2625617,
#  1193401,
#  2083782,
#  2146207,
# ...

# %%
toy_data = data.iloc[rand_idxs]
toy_data.shape
# Out:
# (20000, 150)

# %%
toy_data.to_csv('./toy.csv')
